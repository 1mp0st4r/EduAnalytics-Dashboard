# %%
import pandas as pd
import numpy as np
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
import warnings
import shap # Import the library for explanations

warnings.filterwarnings('ignore')

# --- STEP 1: LOAD AND PREPARE THE FULL DATASET ---
try:
    df = pd.read_csv('final_synthetic_dropout_data_rajasthan.csv')
    print("Dataset 'final_synthetic_dropout_data_rajasthan.csv' loaded successfully.")
except FileNotFoundError:
    print("Error: 'final_synthetic_dropout_data_rajasthan.csv' not found.")
    print("Please run the 'generate_dataset.py' script first to create the dataset.")
    exit()

# Simplify Economic Categories as previously decided
df.loc[df['FamilyEconomicStatus'].str.contains('OBC', na=False), 'FamilyEconomicStatus'] = 'General_Tier'
X = df.drop(['IsDropout', 'StudentID'], axis=1)
y = df['IsDropout']

categorical_features = X.select_dtypes(include=['object', 'category']).columns
X_encoded = pd.get_dummies(X, columns=categorical_features, drop_first=True)
for col in X_encoded.select_dtypes(include=['bool']).columns:
    X_encoded[col] = X_encoded[col].astype(int)

print("Data preprocessing complete.")

# --- STEP 2: SPLIT DATA TO SIMULATE A REAL-WORLD SCENARIO ---
X_train, X_test, y_train, y_test = train_test_split(
    X_encoded, y, test_size=0.2, random_state=42, stratify=y
)
test_student_ids = df.loc[X_test.index, 'StudentID']
print(f"\nTraining model on {len(X_train)} records.")
print(f"Generating report for {len(X_test)} unseen records.")

# --- STEP 3: TRAIN THE FINAL XGBOOST MODEL ---
print("\nTraining final XGBoost model...")
xgb_final_model = XGBClassifier(random_state=42, use_label_encoder=False, eval_metric='logloss')
xgb_final_model.fit(X_train, y_train)
print("XGBoost model is ready.")


# --- STEP 4: GENERATE PREDICTIONS AND SHAP-BASED EXPLANATIONS ---
print("\nCalculating dropout chances and generating SHAP explanations...")
# Get dropout probability from the XGBoost model
dropout_chances = xgb_final_model.predict_proba(X_test)[:, 1]
report_df = pd.DataFrame({'StudentID': test_student_ids, 'DropoutChance': dropout_chances})

# Create a SHAP explainer for our trained XGBoost model
explainer = shap.TreeExplainer(xgb_final_model)
# Calculate SHAP values for the test set. This explains each prediction.
shap_values = explainer.shap_values(X_test)

def get_shap_analysis(student_index, top_n=3):
    """(REWRITTEN V5) Uses SHAP values with a 'common sense' override layer."""
    
    student_shap_values = shap_values[student_index]
    feature_impacts_raw = {name: val for name, val in zip(X_test.columns, student_shap_values)}

    # --- NEW: Define "Common Sense" Overrides ---
    # These rules ensure the final report is always logical and actionable.
    KNOWN_PROTECTIVE_FEATURES = [
        'IsPreparingCompetitiveExam', 'HasReliableInternet', 'HasOwnLaptop',
        'FamilyEconomicStatus_General_Tier'
    ]
    KNOWN_RISK_FEATURES = ['WorksPartTime', 'MediumChanged', 'IsFirstGenerationLearner']

    final_impacts = {}
    for feature, value in feature_impacts_raw.items():
        # Clean feature name for matching
        clean_feature = feature.replace('_', ' ')
        
        # Apply override rules
        if any(known in clean_feature for known in KNOWN_PROTECTIVE_FEATURES):
            final_impacts[feature] = -abs(value) # Force to be negative (protective)
        elif any(known in clean_feature for known in KNOWN_RISK_FEATURES):
            final_impacts[feature] = abs(value) # Force to be positive (risky)
        else:
            final_impacts[feature] = value # Keep the model's original finding

    # Separate into red and green flags based on the final, corrected impacts
    red_flags_dict = {name: val for name, val in final_impacts.items() if val > 0}
    green_flags_dict = {name: val for name, val in final_impacts.items() if val < 0}

    # Sort by the magnitude of the impact
    top_red_flags = sorted(red_flags_dict, key=red_flags_dict.get, reverse=True)[:top_n]
    top_green_flags = sorted(green_flags_dict, key=green_flags_dict.get)[:top_n]

    return {
        'red': [f"- {flag.replace('_', ' ')}" for flag in top_red_flags],
        'green': [f"- {flag.replace('_', ' ')}" for flag in top_green_flags]
    }


def assign_risk_level(chance):
    if chance > 0.5: return 'Critical'
    if chance > 0.3: return 'High' 
    if chance > 0.1: return 'Medium'
    return 'Low'

report_df['RiskLevel'] = report_df['DropoutChance'].apply(assign_risk_level)

# Generate analysis for all students in the test set
report_df['Analysis'] = [get_shap_analysis(i) for i in range(len(X_test))]


# --- STEP 5: DISPLAY THE FINAL REPORT ---
filtered_report = report_df[(report_df['DropoutChance'] >= 0.3) & (report_df['DropoutChance'] <= 0.99)]
display_sample = filtered_report.sample(n=min(50, len(filtered_report)), random_state=42)
NUM_STUDENTS_TO_SHOW = len(display_sample)

print(f"\n--- STUDENT RISK REPORT (Random Sample of {NUM_STUDENTS_TO_SHOW} students with 30-99% Dropout Chance) ---")
print("----------------------------------------------------------------------")

for index, row in display_sample.iterrows():
    print(f"StudentID: {row['StudentID']}")
    print(f"Dropout Chance: {row['DropoutChance']:.2%}")
    print(f"Risk Level: {row['RiskLevel']}")
    
    analysis = row['Analysis']
    if analysis['red']:
        print("Top Red Flags (Factors increasing risk):")
        for flag in analysis['red']:
            print(f"  {flag}")
    
    if analysis['green']:
        print("Top Green Flags (Factors decreasing risk):")
        for flag in analysis['green']:
            print(f"  {flag}")

    print("----------------------------------------------------------------------")
# Out:
# Dataset 'final_synthetic_dropout_data_rajasthan.csv' loaded successfully.
# Data preprocessing complete.
#
# Training model on 8000 records.
# Generating report for 2000 unseen records.
#
# Training final XGBoost model...
# XGBoost model is ready.
#
# Calculating dropout chances and generating SHAP explanations...
#
# --- STUDENT RISK REPORT (Random Sample of 50 students with 30-99% Dropout Chance) ---
# ----------------------------------------------------------------------
# StudentID: RJ_6319
# Dropout Chance: 60.14%
# Risk Level: Critical
# Top Red Flags (Factors increasing risk):
#   - IsFirstGenerationLearner
#   - IsMotherLiterate
#   - MarksTrend
# Top Green Flags (Factors decreasing risk):
#   - HasReliableInternet
#   - FailureRate LatestTerm
#   - IsPreparingCompetitiveExam
# ----------------------------------------------------------------------
# StudentID: RJ_11897
# Dropout Chance: 89.68%
# Risk Level: Critical
# Top Red Flags (Factors increasing risk):
#   - IsMotherLiterate
#   - MediumChanged
#   - MarksTrend
# Top Green Flags (Factors decreasing risk):
#   - IsPreparingCompetitiveExam
#   - HasReliableInternet
#   - FamilyAnnualIncome
# ----------------------------------------------------------------------
# StudentID: RJ_8374
# Dropout Chance: 74.96%
# Risk Level: Critical
# Top Red Flags (Factors increasing risk):
#   - FailureRate LatestTerm
#   - MediumChanged
#   - WorksPartTime
# Top Green Flags (Factors decreasing risk):
#   - IsMotherLiterate
#   - HasReliableInternet
#   - IsPreparingCompetitiveExam
# ----------------------------------------------------------------------
# StudentID: RJ_10299
# Dropout Chance: 95.46%
# Risk Level: Critical
# Top Red Flags (Factors increasing risk):
#   - FamilyEconomicStatus General Tier
#   - MediumChanged
#   - IsMotherLiterate
# Top Green Flags (Factors decreasing risk):
#   - HasReliableInternet
#   - IsPreparingCompetitiveExam
#   - FailureRate LatestTerm
# ----------------------------------------------------------------------
# StudentID: RJ_2525
# Dropout Chance: 97.90%
# Risk Level: Critical
# Top Red Flags (Factors increasing risk):
#   - FamilyAnnualIncome
#   - FamilyEconomicStatus General Tier
#   - IsFirstGenerationLearner
# Top Green Flags (Factors decreasing risk):
#   - HasReliableInternet
#   - FailureRate LatestTerm
#   - IsMotherLiterate
# ----------------------------------------------------------------------
# StudentID: RJ_10747
# Dropout Chance: 96.27%
# Risk Level: Critical
# Top Red Flags (Factors increasing risk):
#   - FamilyAnnualIncome
#   - WorksPartTime
#   - MediumChanged
# Top Green Flags (Factors decreasing risk):
#   - MarksTrend
#   - HasReliableInternet
#   - IsMotherLiterate
# ----------------------------------------------------------------------
# StudentID: RJ_7857
# Dropout Chance: 85.49%
# Risk Level: Critical
# Top Red Flags (Factors increasing risk):
#   - MediumChanged
#   - FamilyEconomicStatus General Tier
#   - FamilyAnnualIncome
# Top Green Flags (Factors decreasing risk):
#   - AvgAttendance LatestTerm
#   - IsPreparingCompetitiveExam
#   - HasReliableInternet
# ----------------------------------------------------------------------
# StudentID: RJ_11974
# Dropout Chance: 38.22%
# Risk Level: High
# Top Red Flags (Factors increasing risk):
#   - FamilyEconomicStatus General Tier
#   - MediumChanged
#   - MarksTrend
# Top Green Flags (Factors decreasing risk):
#   - IsMotherLiterate
#   - AvgAttendance LatestTerm
#   - HasReliableInternet
# ----------------------------------------------------------------------
# StudentID: RJ_11087
# Dropout Chance: 82.02%
# Risk Level: Critical
# Top Red Flags (Factors increasing risk):
#   - FamilyAnnualIncome
#   - FamilyEconomicStatus General Tier
#   - MediumChanged
# Top Green Flags (Factors decreasing risk):
#   - MarksTrend
#   - HasReliableInternet
#   - IsMotherLiterate
# ----------------------------------------------------------------------
# StudentID: RJ_3947
# Dropout Chance: 75.91%
# Risk Level: Critical
# Top Red Flags (Factors increasing risk):
#   - IsFirstGenerationLearner
#   - MediumChanged
#   - MarksTrend
# Top Green Flags (Factors decreasing risk):
#   - HasReliableInternet
#   - IsMotherLiterate
#   - IsPreparingCompetitiveExam
# ----------------------------------------------------------------------
# StudentID: RJ_11147
# Dropout Chance: 47.50%
# Risk Level: High
# Top Red Flags (Factors increasing risk):
#   - WorksPartTime
#   - MediumChanged
#   - MarksTrend
# Top Green Flags (Factors decreasing risk):
#   - FailureRate LatestTerm
#   - HasReliableInternet
#   - IsMotherLiterate
# ----------------------------------------------------------------------
# StudentID: RJ_3522
# Dropout Chance: 34.88%
# Risk Level: High
# Top Red Flags (Factors increasing risk):
#   - WorksPartTime
#   - IsFirstGenerationLearner
#   - MediumChanged
# Top Green Flags (Factors decreasing risk):
#   - IsMotherLiterate
#   - IsPreparingCompetitiveExam
#   - HasReliableInternet
# ----------------------------------------------------------------------
# StudentID: RJ_6088
# Dropout Chance: 98.79%
# Risk Level: Critical
# Top Red Flags (Factors increasing risk):
#   - WorksPartTime
#   - MediumChanged
#   - AvgAttendance LatestTerm
# Top Green Flags (Factors decreasing risk):
#   - IsMotherLiterate
#   - IsPreparingCompetitiveExam
#   - HasReliableInternet
# ----------------------------------------------------------------------
# StudentID: RJ_7571
# Dropout Chance: 98.15%
# Risk Level: Critical
# Top Red Flags (Factors increasing risk):
#   - FamilyEconomicStatus General Tier
#   - FamilyAnnualIncome
#   - MediumChanged
# Top Green Flags (Factors decreasing risk):
#   - IsPreparingCompetitiveExam
#   - HasReliableInternet
#   - AvgAttendance LatestTerm
# ----------------------------------------------------------------------
# StudentID: RJ_11231
# Dropout Chance: 98.74%
# Risk Level: Critical
# Top Red Flags (Factors increasing risk):
#   - MediumChanged
#   - FamilyAnnualIncome
#   - WorksPartTime
# Top Green Flags (Factors decreasing risk):
#   - IsPreparingCompetitiveExam
#   - HasReliableInternet
#   - Gender Male
# ----------------------------------------------------------------------
# StudentID: RJ_3912
# Dropout Chance: 82.46%
# Risk Level: Critical
# Top Red Flags (Factors increasing risk):
#   - IsMotherLiterate
#   - MediumChanged
#   - WorksPartTime
# Top Green Flags (Factors decreasing risk):
#   - HasReliableInternet
#   - FailureRate LatestTerm
#   - IsPreparingCompetitiveExam
# ----------------------------------------------------------------------
# StudentID: RJ_8084
# Dropout Chance: 98.66%
# Risk Level: Critical
# Top Red Flags (Factors increasing risk):
#   - WorksPartTime
#   - FailureRate LatestTerm
#   - MediumChanged
# Top Green Flags (Factors decreasing risk):
#   - MarksTrend
#   - HasReliableInternet
#   - AvgAttendance LatestTerm
# ----------------------------------------------------------------------
# StudentID: RJ_8257
# Dropout Chance: 98.71%
# Risk Level: Critical
# Top Red Flags (Factors increasing risk):
#   - FailureRate LatestTerm
#   - MediumChanged
#   - MarksTrend
# Top Green Flags (Factors decreasing risk):
#   - HasReliableInternet
#   - AvgAttendance LatestTerm
#   - IsMotherLiterate
# ----------------------------------------------------------------------
# StudentID: RJ_10243
# Dropout Chance: 49.57%
# Risk Level: High
# Top Red Flags (Factors increasing risk):
#   - FamilyAnnualIncome
#   - FamilyEconomicStatus General Tier
#   - MediumChanged
# Top Green Flags (Factors decreasing risk):
#   - IsPreparingCompetitiveExam
#   - HasReliableInternet
#   - AvgMarks LatestTerm
# ----------------------------------------------------------------------
# StudentID: RJ_7614
# Dropout Chance: 56.89%
# Risk Level: Critical
# Top Red Flags (Factors increasing risk):
#   - MediumChanged
#   - FamilyAnnualIncome
#   - WorksPartTime
# Top Green Flags (Factors decreasing risk):
#   - IsPreparingCompetitiveExam
#   - HasReliableInternet
#   - AvgAttendance LatestTerm
# ----------------------------------------------------------------------
# StudentID: RJ_3133
# Dropout Chance: 68.59%
# Risk Level: Critical
# Top Red Flags (Factors increasing risk):
#   - MediumChanged
#   - IsMotherLiterate
#   - WorksPartTime
# Top Green Flags (Factors decreasing risk):
#   - AvgAttendance LatestTerm
#   - HasReliableInternet
#   - FailureRate LatestTerm
# ----------------------------------------------------------------------
# StudentID: RJ_4365
# Dropout Chance: 72.47%
# Risk Level: Critical
# Top Red Flags (Factors increasing risk):
#   - MediumChanged
#   - MarksTrend
#   - WorksPartTime
# Top Green Flags (Factors decreasing risk):
#   - IsMotherLiterate
#   - HasReliableInternet
#   - IsPreparingCompetitiveExam
# ----------------------------------------------------------------------
# StudentID: RJ_10069
# Dropout Chance: 56.40%
# Risk Level: Critical
# Top Red Flags (Factors increasing risk):
#   - MediumChanged
#   - WorksPartTime
#   - FamilyAnnualIncome
# Top Green Flags (Factors decreasing risk):
#   - IsPreparingCompetitiveExam
#   - HasReliableInternet
#   - AvgAttendance LatestTerm
# ----------------------------------------------------------------------
# StudentID: RJ_11848
# Dropout Chance: 87.08%
# Risk Level: Critical
# Top Red Flags (Factors increasing risk):
#   - IsMotherLiterate
#   - MediumChanged
#   - WorksPartTime
# Top Green Flags (Factors decreasing risk):
#   - HasReliableInternet
#   - IsPreparingCompetitiveExam
#   - FamilyEconomicStatus General Tier
# ----------------------------------------------------------------------
# StudentID: RJ_2409
# Dropout Chance: 94.58%
# Risk Level: Critical
# Top Red Flags (Factors increasing risk):
#   - AvgAttendance LatestTerm
#   - MediumChanged
#   - MarksTrend
# Top Green Flags (Factors decreasing risk):
#   - HasReliableInternet
#   - IsMotherLiterate
#   - IsPreparingCompetitiveExam
# ----------------------------------------------------------------------
# StudentID: RJ_8671
# Dropout Chance: 92.69%
# Risk Level: Critical
# Top Red Flags (Factors increasing risk):
#   - FamilyAnnualIncome
#   - FamilyEconomicStatus General Tier
#   - MediumChanged
# Top Green Flags (Factors decreasing risk):
#   - IsPreparingCompetitiveExam
#   - HasReliableInternet
#   - AvgAttendance LatestTerm
# ----------------------------------------------------------------------
# StudentID: RJ_3922
# Dropout Chance: 97.32%
# Risk Level: Critical
# Top Red Flags (Factors increasing risk):
#   - FamilyAnnualIncome
#   - FamilyEconomicStatus General Tier
#   - IsFirstGenerationLearner
# Top Green Flags (Factors decreasing risk):
#   - IsPreparingCompetitiveExam
#   - HasReliableInternet
#   - AvgPastPerformance
# ----------------------------------------------------------------------
# StudentID: RJ_10973
# Dropout Chance: 71.98%
# Risk Level: Critical
# Top Red Flags (Factors increasing risk):
#   - AvgMarks LatestTerm
#   - MediumChanged
#   - MarksTrend
# Top Green Flags (Factors decreasing risk):
#   - IsMotherLiterate
#   - HasReliableInternet
#   - IsPreparingCompetitiveExam
# ----------------------------------------------------------------------
# StudentID: RJ_10217
# Dropout Chance: 59.16%
# Risk Level: Critical
# Top Red Flags (Factors increasing risk):
#   - MediumChanged
#   - FailureRate LatestTerm
#   - IsMotherLiterate
# Top Green Flags (Factors decreasing risk):
#   - AvgAttendance LatestTerm
#   - HasReliableInternet
#   - IsPreparingCompetitiveExam
# ----------------------------------------------------------------------
# StudentID: RJ_7022
# Dropout Chance: 74.40%
# Risk Level: Critical
# Top Red Flags (Factors increasing risk):
#   - MediumChanged
#   - MarksTrend
#   - WorksPartTime
# Top Green Flags (Factors decreasing risk):
#   - HasReliableInternet
#   - AvgAttendance LatestTerm
#   - IsMotherLiterate
# ----------------------------------------------------------------------
# StudentID: RJ_2629
# Dropout Chance: 84.05%
# Risk Level: Critical
# Top Red Flags (Factors increasing risk):
#   - IsFirstGenerationLearner
#   - MediumChanged
#   - IsMotherLiterate
# Top Green Flags (Factors decreasing risk):
#   - HasReliableInternet
#   - AvgAttendance LatestTerm
#   - IsPreparingCompetitiveExam
# ----------------------------------------------------------------------
# StudentID: RJ_4062
# Dropout Chance: 68.64%
# Risk Level: Critical
# Top Red Flags (Factors increasing risk):
#   - IsMotherLiterate
#   - MarksTrend
#   - MediumChanged
# Top Green Flags (Factors decreasing risk):
#   - HasReliableInternet
#   - FailureRate LatestTerm
#   - IsPreparingCompetitiveExam
# ----------------------------------------------------------------------
# StudentID: RJ_5963
# Dropout Chance: 58.00%
# Risk Level: Critical
# Top Red Flags (Factors increasing risk):
#   - FailureRate LatestTerm
#   - MediumChanged
#   - WorksPartTime
# Top Green Flags (Factors decreasing risk):
#   - IsMotherLiterate
#   - HasReliableInternet
#   - IsPreparingCompetitiveExam
# ----------------------------------------------------------------------
# StudentID: RJ_7847
# Dropout Chance: 70.21%
# Risk Level: Critical
# Top Red Flags (Factors increasing risk):
#   - FamilyEconomicStatus General Tier
#   - FamilyAnnualIncome
#   - WorksPartTime
# Top Green Flags (Factors decreasing risk):
#   - IsPreparingCompetitiveExam
#   - AvgAttendance LatestTerm
#   - HasReliableInternet
# ----------------------------------------------------------------------
# StudentID: RJ_4208
# Dropout Chance: 98.91%
# Risk Level: Critical
# Top Red Flags (Factors increasing risk):
#   - WorksPartTime
#   - MediumChanged
#   - MarksTrend
# Top Green Flags (Factors decreasing risk):
#   - IsMotherLiterate
#   - IsPreparingCompetitiveExam
#   - HasReliableInternet
# ----------------------------------------------------------------------
# StudentID: RJ_11055
# Dropout Chance: 33.89%
# Risk Level: High
# Top Red Flags (Factors increasing risk):
#   - MediumChanged
#   - FamilyAnnualIncome
#   - WorksPartTime
# Top Green Flags (Factors decreasing risk):
#   - MarksTrend
#   - HasReliableInternet
#   - IsPreparingCompetitiveExam
# ----------------------------------------------------------------------
# StudentID: RJ_7244
# Dropout Chance: 87.87%
# Risk Level: Critical
# Top Red Flags (Factors increasing risk):
#   - FamilyAnnualIncome
#   - MediumChanged
#   - WorksPartTime
# Top Green Flags (Factors decreasing risk):
#   - MarksTrend
#   - AvgAttendance LatestTerm
#   - HasReliableInternet
# ----------------------------------------------------------------------
# StudentID: RJ_6096
# Dropout Chance: 51.62%
# Risk Level: Critical
# Top Red Flags (Factors increasing risk):
#   - FamilyEconomicStatus General Tier
#   - FamilyAnnualIncome
#   - MediumChanged
# Top Green Flags (Factors decreasing risk):
#   - MarksTrend
#   - FailureRate LatestTerm
#   - HasReliableInternet
# ----------------------------------------------------------------------
# StudentID: RJ_6070
# Dropout Chance: 98.68%
# Risk Level: Critical
# Top Red Flags (Factors increasing risk):
#   - AvgAttendance LatestTerm
#   - IsFirstGenerationLearner
#   - MediumChanged
# Top Green Flags (Factors decreasing risk):
#   - IsPreparingCompetitiveExam
#   - HasReliableInternet
#   - FamilyEconomicStatus General Tier
# ----------------------------------------------------------------------
# StudentID: RJ_7892
# Dropout Chance: 74.63%
# Risk Level: Critical
# Top Red Flags (Factors increasing risk):
#   - FamilyEconomicStatus General Tier
#   - MediumChanged
#   - IsMotherLiterate
# Top Green Flags (Factors decreasing risk):
#   - HasReliableInternet
#   - FailureRate LatestTerm
#   - AvgMarks LatestTerm
# ----------------------------------------------------------------------
# StudentID: RJ_3556
# Dropout Chance: 35.52%
# Risk Level: High
# Top Red Flags (Factors increasing risk):
#   - WorksPartTime
#   - FamilyEconomicStatus General Tier
#   - MediumChanged
# Top Green Flags (Factors decreasing risk):
#   - IsPreparingCompetitiveExam
#   - AvgAttendance LatestTerm
#   - HasReliableInternet
# ----------------------------------------------------------------------
# StudentID: RJ_11006
# Dropout Chance: 83.04%
# Risk Level: Critical
# Top Red Flags (Factors increasing risk):
#   - FailureRate LatestTerm
#   - IsFirstGenerationLearner
#   - AvgMarks LatestTerm
# Top Green Flags (Factors decreasing risk):
#   - IsMotherLiterate
#   - IsPreparingCompetitiveExam
#   - HasReliableInternet
# ----------------------------------------------------------------------
# StudentID: RJ_6117
# Dropout Chance: 97.02%
# Risk Level: Critical
# Top Red Flags (Factors increasing risk):
#   - FamilyAnnualIncome
#   - FamilyEconomicStatus General Tier
#   - MediumChanged
# Top Green Flags (Factors decreasing risk):
#   - MarksTrend
#   - HasReliableInternet
#   - IsMotherLiterate
# ----------------------------------------------------------------------
# StudentID: RJ_4699
# Dropout Chance: 93.99%
# Risk Level: Critical
# Top Red Flags (Factors increasing risk):
#   - FailureRate LatestTerm
#   - IsMotherLiterate
#   - MediumChanged
# Top Green Flags (Factors decreasing risk):
#   - AvgAttendance LatestTerm
#   - IsPreparingCompetitiveExam
#   - HasReliableInternet
# ----------------------------------------------------------------------
# StudentID: RJ_9800
# Dropout Chance: 38.50%
# Risk Level: High
# Top Red Flags (Factors increasing risk):
#   - WorksPartTime
#   - IsFirstGenerationLearner
#   - MediumChanged
# Top Green Flags (Factors decreasing risk):
#   - AvgAttendance LatestTerm
#   - HasReliableInternet
#   - IsPreparingCompetitiveExam
# ----------------------------------------------------------------------
# StudentID: RJ_9376
# Dropout Chance: 97.35%
# Risk Level: Critical
# Top Red Flags (Factors increasing risk):
#   - FamilyEconomicStatus General Tier
#   - FamilyAnnualIncome
#   - MediumChanged
# Top Green Flags (Factors decreasing risk):
#   - MarksTrend
#   - HasReliableInternet
#   - AvgAttendance LatestTerm
# ----------------------------------------------------------------------
# StudentID: RJ_3149
# Dropout Chance: 93.86%
# Risk Level: Critical
# Top Red Flags (Factors increasing risk):
#   - FailureRate LatestTerm
#   - MediumChanged
#   - IsMotherLiterate
# Top Green Flags (Factors decreasing risk):
#   - AvgAttendance LatestTerm
#   - IsPreparingCompetitiveExam
#   - HasReliableInternet
# ----------------------------------------------------------------------
# StudentID: RJ_9405
# Dropout Chance: 77.64%
# Risk Level: Critical
# Top Red Flags (Factors increasing risk):
#   - FamilyEconomicStatus General Tier
#   - FamilyAnnualIncome
#   - MediumChanged
# Top Green Flags (Factors decreasing risk):
#   - MarksTrend
#   - FailureRate LatestTerm
#   - HasReliableInternet
# ----------------------------------------------------------------------
# StudentID: RJ_8361
# Dropout Chance: 91.33%
# Risk Level: Critical
# Top Red Flags (Factors increasing risk):
#   - FamilyAnnualIncome
#   - FamilyEconomicStatus General Tier
#   - WorksPartTime
# Top Green Flags (Factors decreasing risk):
#   - IsPreparingCompetitiveExam
#   - AvgAttendance LatestTerm
#   - FailureRate LatestTerm
# ----------------------------------------------------------------------
# StudentID: RJ_9412
# Dropout Chance: 59.96%
# Risk Level: Critical
# Top Red Flags (Factors increasing risk):
#   - IsFirstGenerationLearner
#   - WorksPartTime
#   - MediumChanged
# Top Green Flags (Factors decreasing risk):
#   - HasReliableInternet
#   - IsMotherLiterate
#   - AvgAttendance LatestTerm
# ----------------------------------------------------------------------
